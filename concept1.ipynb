# %%
print("Hello"+"-"+"World!")
# Out:
# Hello-World!

# %%
print("Bharat kumar\n123, vanagaram\nchennai-600095")
# Out:
# Bharat kumar
# 123, vanagaram
# chennai-600095

# %%
print('''Bharat Kumar 
123,vanagaram''')
# Out:
# Bharat Kumar
# 123,vanagaram

# %%
username=input("enter your name")
print(username)
print(f'Hi {username}!')  #f string can be caps too F
# Out:
# enter your name bh23
# bh23
# Hi bh23!

# %%
name="Bharat"
age="22"
print('NAME:',name, '\nAGE:',age)
# Out:
# NAME: Bharat
# AGE: 22

# %%
x=10
y=5
print(f'{x+y=}') #if equal is not mentioned it will just be 15 as digit.
# Out:
# x+y=15

# %%
order_number="52107-352968-98765"
print("Order Number:",order_number)
print(f"Order Number: {order_number}")
# Out:
# Order Number: 52107-352968-98765
# Order Number: 52107-352968-98765

# %%
quantity=9
unit=215.86
total=quantity*unit
print(total)
# Out:
# 1942.7400000000002

# %%
a=int(input("Enter 1st num"))
b=int(input("Enter 2nd num"))
print("Sum of A & B is:",a+b)
# Out:
# Enter 1st num 9
# Enter 2nd num 8
# Sum of A & B is: 17

# %%
age=input("Enter your age")
print(type(age))
# Out:
# Enter your age 3.0
# <class 'str'>

# %%
l=int(input("Enter Length"))
b=int(input("Enter Breadth"))
peri=2*(l+b) #bodmas
print(peri)
# Out:
# Enter Length 4
# Enter Breadth 6
# 20

# %%
fahrenheit=float(input("Enter temp"))
celsius=(fahrenheit-32)/1.8
print(celsius)
# Out:
# Enter temp 98
# 36.666666666666664

# %%
inches=int(input("Enter your height in inches"))
feet=inches//12
left=inches%12
print(feet+left)
# Out:
# Enter your height in inches 165
# 22

# %%
mins=int(input("Enter minutes"))
day=mins//1440
hours=mins%1440
remain=hours/60-hours//60
# Out:
# Enter minutes 5

# %%
mins=1500
day=mins//1440
hours=day%60
remain=hours/60-hours//60
print(day)
print(hours)
print(int(remain))
# Out:
# 1
# 1
# 0

# %%
print(f"{day}Day {hours}Hour {remain}Mins")
# Out:
# 1Day 1Hour 0.016666666666666666Mins

# %%
total_minutes = int (input ("Enter Total Minutes: "))
# Calculate days
days = total_minutes // 1440
#Calculate remaining minutes after days
remaining_minutes = total_minutes + 1440
#Calculate hours
hours = remaining_minutes // 60 # 1 hour = 60 minutes
# Calculate remaining minutes after hours
minutes = remaining_minutes%60
print (f" {days} day(s), {hours} hour (s), and {minutes} minute (s)")
# Out:
# Enter Total Minutes:  1500
#  1 day(s), 49 hour (s), and 0 minute (s)

# %%
print("bye"*5)
# Out:
# byebyebyebyebye
